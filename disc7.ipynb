# %% [markdown]
# # Plotting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Matplotlib is strongly object oriented and its principal objects are `Figure` and `Axes`.
# ###  Figure -- "canvas"
# - Place objects on it (usually `axes`)
# - Save its contents (with `savefig`)
# ### Axes -- "tool kit", "the plot"
# - `.plot`, `.scatter`, `.hist`
# - You can place many `axes` inside the same `figure`

# %% [markdown]
# ## Useful resource [matplot](https://matplotlib.org/faq/usage_faq.html#usage)

# %%
x = np.arange(1, 100)
y = np.sqrt(x)
            
figure = plt.figure()
axe1 = figure.add_subplot(111)
axe1.plot(x, y)

# %%
fig, ax = plt.subplots()
ax.plot(x,y)

# %% [markdown]
# ## The `plt` interface automatically instantiates a `figure` and an `axe`.

# %%
# same thing
plt.plot(x, y)

# %% [markdown]
# ## Hierarchy in `matplotlib`

# %% [markdown]
# <img src="attachment:image.png" width="400">

# %%
fig, ax = plt.subplots() # make Figure and Axes which belongs to 'fig'

# %%
print('fig.axes:', fig.axes)
print('ax.figure:', ax.figure)
print('ax.xaxis:', ax.xaxis)
print('ax.yaxis:', ax.yaxis)
print('ax.xaxis.axes:', ax.xaxis.axes)
print('ax.yaxis.axes:', ax.yaxis.axes)
print('ax.xaxis.figure:', ax.xaxis.figure)
print('ax.yaxis.figure:', ax.yaxis.figure)
print('fig.xaxis:', fig.xaxis)
# Out:
# fig.axes: [<matplotlib.axes._subplots.AxesSubplot object at 0x11bea6b10>]
# ax.figure: Figure(432x288)
# ax.xaxis: XAxis(54.000000,36.000000)
# ax.yaxis: YAxis(54.000000,36.000000)
# ax.xaxis.axes: AxesSubplot(0.125,0.125;0.775x0.755)
# ax.yaxis.axes: AxesSubplot(0.125,0.125;0.775x0.755)
# ax.xaxis.figure: Figure(432x288)
# ax.yaxis.figure: Figure(432x288)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-15f479212324> in <module>
#       7 print('ax.xaxis.figure:', ax.xaxis.figure)
#       8 print('ax.yaxis.figure:', ax.yaxis.figure)
# ----> 9 print('fig.xaxis:', fig.xaxis)
#
# AttributeError: 'Figure' object has no attribute 'xaxis'

# %%
xax = ax.xaxis
print('xax.label:', xax.label)
print('xax.majorTicks:\n', xax.majorTicks) # seven major ticks (from 0 to 6) and two invisible ticks locating outside of the figure
print('xax.minorTicks:\n', xax.minorTicks)
# Out:
# xax.label: Text(0.5, 3.1999999999999993, '')
# xax.majorTicks:
#  [<matplotlib.axis.XTick object at 0x11be63350>, <matplotlib.axis.XTick object at 0x11bfa9950>, <matplotlib.axis.XTick object at 0x11bfe75d0>, <matplotlib.axis.XTick object at 0x11c0ad210>, <matplotlib.axis.XTick object at 0x11c0ad950>, <matplotlib.axis.XTick object at 0x11c0b05d0>]
# xax.minorTicks:
# ...

# %% [markdown]
# ## From these results, we can expect following rules about the hierarchy of `Figure`, `Axes`, and `Axis`.
#
# - `Figure` knows `Axes` but not `Axis`.
# - `Axes` knows `Figure` and `Axis` both.
# - `Axis` knows `Axes` and `Figure` both.
# - `Figure` can contain multiple `Axes` because `fig.axes` is a list of `Axes`.
# - `Axes` can belong to only single `Figure` because `ax.figure` is not a list.
# - `Axes` can have one `XAxis` and `YAxis` respectively for similar reason.
# - `XAxis` and `YAxis` can belong to single `Axes` and, accordingly, single `Figure`.

# %%
x = np.linspace(0, 2*np.pi, 100)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
print('ax.lines before plot:\n', ax.lines) # empty
line1, = ax.plot(x, np.sin(x), label='1st plot') # add Line2D in ax.lines
print('ax.lines after 1st plot:\n', ax.lines)
line2, = ax.plot(x, np.sin(x+np.pi/8), label='2nd plot') # add another Line2D
print('ax.lines after 2nd plot:\n', ax.lines)
ax.legend()
print('line1:', line1)
print('line2:', line2)
# Out:
# ax.lines before plot:
#  []
# ax.lines after 1st plot:
# ...
# ax.lines after 2nd plot:
#  [<matplotlib.lines.Line2D object at 0x11c2d12d0>, <matplotlib.lines.Line2D object at 0x11c2d1890>]
# line1: Line2D(1st plot)
# line2: Line2D(2nd plot)

# %% [markdown]
# ### `fig.legend` versus `ax.legend`

# %%
x = np.linspace(0, 2*np.pi, 100)

fig = plt.figure()

ax1 = fig.add_subplot(121)
ax1.plot(x, 2*np.cos(x), c='C1', label='2*cos(x)') 


ax2 = fig.add_subplot(122)
ax2.plot(x, np.sin(x), label='sin(x)')

# cf. 'CN' notation

# ax1.legend()
# ax2.legend()

# fig.legend()

# %% [markdown]
# <img src="attachment:image.png" width="700">

# %% [markdown]
# <img src="attachment:image.png" width="200">

# %%
x = np.linspace(0, 2*np.pi, 100)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
line1, = ax.plot(x, np.sin(x), label='1st plot') # add Line2D in Axes.lines
line2, = ax.plot(x, np.sin(x+np.pi/8), label='2nd plot') # add another Line2D 

scat = ax.scatter(x, np.random.rand(len(x)), label='scatter') # add PathCollection in Axes.collections
ax.legend()

ax.set_xlabel('x value')
ax.set_ylabel('y value')
# Out:
# Text(0.5, 0, 'x value')
# Text(0, 0.5, 'y value')

# %% [markdown]
# <img src="attachment:image.png" width="600">

# %%
x = np.linspace(0, 2*np.pi, 100)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
line1, = ax.plot(x, np.sin(x), label='line1') # X range: 0 to 2pi
ax.set_xticks([0, 0.5*np.pi, np.pi, 1.5*np.pi, 2*np.pi])
line2, = ax.plot(1.5*x, np.sin(x), label='line2') # X range: 0 to 3pi
ax.legend()

# %% [markdown]
# ## Pyplot interface

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k', label='line1')
plt.legend()
plt.xlabel('Month')
plt.title('Average monthly cost for years 2000-2018')
plt.ylabel('Cost per Pound $')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--', label='line2')

plt.xlabel('Month')
plt.title('Average monthly cost for years 2000-2018')
plt.ylabel('Cost per Pound $')
plt.legend()
plt.show()
# Out:
# ...
# Text(0.5, 0, 'Month')
# Text(0.5, 1.0, 'Average monthly cost for years 2000-2018')
# Text(0, 0.5, 'Cost per Pound $')
# Text(0.5, 0, 'Month')
# Text(0.5, 1.0, 'Average monthly cost for years 2000-2018')
# Text(0, 0.5, 'Cost per Pound $')

# %% [markdown]
# ### This is a "non-00" interface. You only need to know which "state" you are in, which is why this style is also called "stateful interface". Here, a "state" means which figure and subplot you are currently in.

# %% [markdown]
# ### [source](https://dev.to/skotaro/artist-in-matplotlib---something-i-wanted-to-know-before-spending-tremendous-hours-on-googling-how-tos--31oo)

# %%
import seaborn as sns

# %% [markdown]
# ## Seaborn is a high-level interface to Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# ## Keys Features
# * Seaborn is a statistical plotting library
# * It has beautiful default styles
# * It also is designed to work very well with Pandas dataframe objects.

# %%
x = np.array([0,1,2])
y = np.array([100,200,300])
X,Y = np.meshgrid(x,y)

# %%
X
# Out:
# array([[0, 1, 2],
#        [0, 1, 2],
#        [0, 1, 2]])

# %%
Y
# Out:
# array([[100, 100, 100],
#        [200, 200, 200],
#        [300, 300, 300]])

# %%
x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)
xx, yy = np.meshgrid(x, y, sparse=True)

# %%
z = np.sin(xx**2 + yy**2) / (xx**2 + yy**2)
h = plt.contourf(x,y,z)

# %%
plt.imshow(z)

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['A','B']).cumsum()

# %%
df.iloc[0].plot.bar()

# %%
jn = np.random.multivariate_normal([0,0], cov = [[1,0.7],[0.7,1]], size=1000)

# %%
df = pd.DataFrame(jn, columns=['x','y'])

# %%
import seaborn as sns

# %%
sns.jointplot('x','y',data=df, kind='kde')

# %%
tips = sns.load_dataset("tips")
tips

# %%
iris = sns.load_dataset("iris")

# %%
g = sns.FacetGrid(tips, col='sex',margin_titles=True)
g.map(sns.distplot, 'perc', bins=20)
